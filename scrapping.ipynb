# %%
import pandas as pd

# %%
data = pd.read_csv('nasdaqtraded_full.csv', sep='|')
data
# Out:
#                           Nasdaq Traded Symbol  \
# 0                                     Y      A
# 1                                     Y     AA
# 2                                     Y   AAAU
# 3                                     Y   AACG
# 4                                     Y   AADR
# ...                                 ...    ...
# 8908                                  Y  ZXZZT
# 8909                                  Y   ZYME
# 8910                                  Y   ZYNE
# 8911                                  Y   ZYXI
# 8912  File Creation Time: 0304202014:02    NaN
#
#                                           Security Name Listing Exchange  \
# 0               Agilent Technologies, Inc. Common Stock                N
# 1                       Alcoa Corporation Common Stock                 N
# 2                          Perth Mint Physical Gold ETF                P
# 3     ATA Creativity Global - American Depositary Sh...                Q
# ...

# %%
symbols = data.loc[data['ETF'] == 'Y', 'Symbol'].tolist()

symbols
# Out:
# ['AAAU',
#  'AADR',
#  'AAXJ',
#  'ABEQ',
#  'ACES',
#  'ACIO',
#  'ACSG',
#  'ACSI',
#  'ACT',
#  'ACWF',
#  'ACWI',
#  'ACWV',
#  'ACWX',
#  'ADME',
#  'ADRE',
#  'AESR',
#  'AFIF',
#  'AFK',
#  'AFLG',
#  'AFMC',
#  'AFSM',
#  'AFTY',
#  'AGG',
#  'AGGP',
#  'AGGY',
#  'AGND',
#  'AGQ',
#  'AGT',
#  'AGZ',
#  'AGZD',
#  'AIA',
#  'AIEQ',
#  'AIIQ',
#  'AIQ',
#  'AIRR',
#  'ALFA',
#  'ALTS',
#  'ALTY',
#  'AMCA',
#  'AMLP',
#  'AMOM',
#  'AMZA',
#  'ANGL',
#  'AOA',
#  'AOK',
#  'AOM',
#  'AOR',
#  'ARCM',
#  'ARGT',
#  'ARKF',
#  'ARKG',
#  'ARKK',
#  'ARKQ',
#  'ARKW',
#  'ARMR',
#  'ASEA',
#  'ASET',
#  'ASHR',
#  'ASHS',
#  'ASHX',
#  'AUSF',
#  'AVDE',
#  'AVDV',
#  'AVEM',
#  'AVUS',
#  'AVUV',
#  'AWAY',
#  'AWTM',
#  'AXJL',
#  'BAB',
#  'BAPR',
#  'BATT',
#  'BAUG',
#  'BBAX',
#  'BBC',
#  'BBCA',
#  'BBEU',
#  'BBH',
#  'BBIN',
#  'BBJP',
#  'BBP',
#  'BBRE',
#  'BBSA',
#  'BBUS',
#  'BCD',
#  'BCI',
#  'BDCY',
#  'BDEC',
#  'BDRY',
#  'BFEB',
#  'BFIT',
#  'BFOR',
# ...

# %%
len(symbols)
# Out:
# 2193
